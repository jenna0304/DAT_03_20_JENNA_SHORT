# %%
#imports
from __future__ import division
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import pylab as pl
import numpy as np
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# Contaminated water can have many adverse health effects such as developmental effects to fetuses during pregnancy or to breastfed infants, kidney cancer, liver effects, immune effects, and thyroid effects. It is difficult to predict what may be causing the amount of days during which an area is under a contamination advisory.
#
# Data provided by the US Environmental Protection Agency includes data about each counties' water, land and population. There are many factors that may predict the amount of days per contamination advisory event, and first I will be determining if the number (in pounds) of herbicides, insecticides and fungicides applied has an affect on the amount of days per contamination advisory event. I will also go on to determine what other factors may predict contamination advisories, in order to find the most predictive feature. The objective here is to determine which of the features (either alone or combined) represented in this data set can most accurately predict the amount of days per contamination advisory. I will therefore be predicting a continuous number.
#
# While I do not have any direct experience working with water contamination issues, I am very interested in the ways we can improve the cleanliness of our water since it can affect huge populations. Research in this field often looks at storm water runoff which has been shown to increase water contamination since the land carries bacteria from sewage that can be carried into the water. The type of work done in a certain area can also have an impact on contamination, in that mining activities and burning fossil fuels can lead to acid rain. This data set includes features that show what percent of the population works in a particular industry, and it also includes the amount of chemicals present in a particular area's rainfall.
#
# The names of the features are convolted so I will need to rename the features that I want to work with. Also, some of the data was already log and or natural log transformed so I need to determine if this is an issue. I would also like to look at the relationships discussed in a statewide manner rather than just on an individual county level.
#
# One of the assumptions that I am making with this data is that the sampled population is representative of the true population. I have to assume this because I did not collect the data and I do not currently have the methods that were used to collect the data (but I can research this). Since this data was collected in 2005, I am assuming that 2005 was a year that is representative of all other years. However, something unknown may have happened this year that caused it to present abnormal data.
#
# I will consider this project a success if I am able to visualize a significant relationship (p-value < .05) between my features and the dependent variable (days per contamination event). I hope to find a combination of features that will predict the outcome more than any of the individual features. The features I will investigate besides pesticides will be the number of sewage permits per 1000km stream length, number of days per rain advisory event, mg/L of sulfates and nitrates present in the rainfall, acres irrigated per county acres (percentage), and proportion of all roads that are highways or secondary roads.
#
# Some of my first steps:
#
# 1. Visualize the relationship between the features and the response with scatterplots
# 2. Find out how strong the relationships are
# 3. Use cross validation to find a mean MSE and R2 for the model
# 4. Use lasso and ridge regularization
# 5. use grid search to find best alphas
# 4. Use the model for prediction
# 3. Find p-values for the relationships
#
#
# Dependent variables:
# hg_ln_ave
#
#
# Independent variables:
# pct_irrigated_acres_ln (percentage of irrigated land in the county)
# Pct_AU_ln (animal units per county as a percentage)
# herbicides_ln (herbicides supplied in pounds)
# mean_as_ln (mean levels of arsenic in the land)
# Mean_pb_ln (Mean level of lead from sampled county sources, in the land (ppm))
# A_NO2_mean_ln - Nitrogen dioxide (parts per billion 5 year average)
# A_CN_ln - Cyanide compounds (tons emitted per year)
# A_Diesel_ln - Diesel engine emissions (tons emitted per year)
# pct_disease_acres_ln - Chemicals used to control Diseases in crops and orchards

# %%
data = pd.read_csv("../dataset/EQIDATA_ALL_DOMAINS_2014MARCH11.csv")
data.head()
# Out:
#    stfips     county_name state  fips  cat_rucc  a_teca_ln  a_112tca_ln  \
# 0    1001  Autauga County    AL  1001         1  -4.385941    -5.052391
# 1    1003  Baldwin County    AL  1003         2  -4.385456   -14.249940
# 2    1005  Barbour County    AL  1005         3  -4.943471   -10.852820
# 3    1007     Bibb County    AL  1007         1  -5.952906    -9.329214
# 4    1009   Blount County    AL  1009         1  -5.251164   -14.007340
#
#    a_dbcp_ln  a_tdi_ln  a_2clacephen_ln        ...         med_hh_value  \
# 0  -13.61030 -8.087206        -31.70556        ...                94800
# 1  -13.61030 -8.208811        -16.06089        ...               122500
# 2  -13.53285 -9.421164        -31.70556        ...                68600
# 3  -13.61030 -9.428741        -16.09672        ...                74600
# 4  -13.61030 -8.590843        -16.15294        ...                86800
#
#    med_hh_inc  pct_pers_lt_pov  pct_no_eng  pct_hs_more  pct_unemp  med_rooms  \
# 0       42013             10.9         2.8         78.7        4.9        5.8
# 1       40250             10.1         4.0         82.0        4.3        5.3
# 2       25101             26.8         3.6         64.7        5.7        5.3
# 3       31420             20.6         1.8         63.2        6.2        5.4
# 4       35241             11.7         5.6         70.4        4.8        5.5
#
#    work_out_co  pct_mt_10units_log  violent_rate_log
# 0         60.3            0.300105          6.067441
# 1         27.3            2.521721          6.185848
# 2         16.5           -0.051293          5.844631
# 3         59.4            0.717840          6.225608
# 4         59.7           -0.287682          1.186318
#
# [5 rows x 227 columns]

# %%
data.shape
# Out:
# (3141, 227)

# %%
data1 = data[['hg_ln_ave','a_so2_mean_ln','w_alpha_ln','fungicides_ln','ca_ln_ave','mean_mg_pct_ln','pct_irrigated_acres_ln','herbicides_ln','a_diesel_ln','pct_disease_acres_ln']]

# %%
data1.shape
# Out:
# (3141, 10)

# %%
data1.dropna()
# Out:
#       hg_ln_ave  a_so2_mean_ln  w_alpha_ln  fungicides_ln  ca_ln_ave  \
# 0      3.584468       2.366601   -6.907755       2.314664  -2.430771
# 1      3.579431       2.841814    0.984323       8.670521  -2.352988
# 2      3.494634       3.146611    1.139754       2.260807  -2.492509
# 3      3.606218       2.032213   -0.355247       0.106351  -2.381515
# 4      3.565559       2.187600    1.098946       2.996326  -2.387422
# 5      3.538714       3.048628   -6.907755       1.748370  -2.477937
# 6      3.554763       2.626942   -6.907755       2.375543  -2.398327
# 7      3.576413       3.098401    0.788912       2.917890  -2.436524
# 8      3.579367       3.683746    1.098946       1.852420  -2.491914
# 9      3.589603       3.546137    0.470628       3.311528  -2.452983
# 10     3.594113       2.085041   -0.429246       2.420089  -2.452000
# 11     3.573391       3.048311   -6.907755      -3.393229  -2.393673
# 12     3.571325       2.889002    1.224069       0.013508  -2.372257
# 13     3.574206       3.037730    1.098946       1.852420  -2.442873
# 14     3.602089       3.631574   -1.604450       0.061007  -2.460479
# 15     3.511695       2.693758   -0.551648       2.566074  -2.412802
# 16     3.518625       0.719623    1.098946       3.971850  -2.297683
# 17     3.541273       2.937922   -6.907755       0.061007  -2.408339
# 18     3.593497       2.541952   -6.907755      -3.393229  -2.464580
# 19     3.535116       2.842655   -6.907755       2.373475  -2.415285
# 20     3.537710       2.640163   -6.907755       2.279614  -2.393886
# 21     3.560711       1.989746    1.098946       6.915764  -2.368253
# 22     3.492784       2.777889    1.098946       2.495174  -2.474589
# 23     3.594584       2.450176   -6.907755       3.236527  -2.418834
# 24     3.567361       2.701623   -6.907755       7.843035  -2.416530
# 25     3.570206       2.662997    0.949854       2.078584  -2.478851
# 26     3.533828       3.188832   -1.200645       3.274986  -2.416161
# 27     3.577585       2.762861   -1.046969       3.899606  -2.413874
# 28     3.558270       1.897962    0.454890       2.700008  -2.369166
# 29     3.526614       1.131472    1.098946       2.583818  -2.309274
# ...         ...            ...         ...            ...        ...
# 3111   3.137974       3.685817   -6.907755       7.911993  -1.439375
# 3112   3.307209       7.820592   -6.907755       5.734671  -1.256517
# 3113   3.323509       7.073321   -6.907755       5.218338  -1.203442
# 3114   3.336159       6.546296   -6.907755       8.606822  -1.363797
# 3115   3.286629       6.525309   -6.907755      11.878620  -1.306273
# 3116   3.310790       7.295657   -6.907755       7.319858  -1.335991
# 3117   3.249911       5.672994   -6.907755       7.222423  -1.298627
# 3118   2.086613       3.318167    0.742413      -3.393229  -1.338467
# 3119   1.302105       4.751734   -6.907755      -3.393229  -1.438007
# 3120   1.616568       6.704130    0.422650      -3.393229  -1.343171
# 3121   2.020077       3.535277    0.000999      -3.393229  -1.404857
# 3122   1.789016       4.671449    1.029976      -3.393229  -1.229099
# 3123   1.656478       6.250045   -6.907755      -3.393229  -1.305601
# 3124   1.437680       6.819974    0.914912       1.965993  -1.386509
# 3125   2.048530       3.776157    0.875417       6.579269  -1.202082
# 3126   1.343374       5.613060   -6.907755      -3.393229  -1.449963
# 3127   1.549435       4.831542   -6.907755      -3.393229  -1.425924
# 3128   2.090559       3.094494    2.446772       6.984719  -1.138186
# 3129   1.255225       4.382509    0.582154      -3.393229  -1.276343
# 3130   1.717287       4.479234    0.929931      -3.393229  -1.341203
# 3131   1.890452       5.471487   -6.907755      -3.393229  -1.221951
# 3132   1.096953       4.086916    0.111243       5.886168  -1.446165
# 3133   2.005558       3.710928    0.000999      -3.393229  -1.258529
# 3134   1.390054       4.503852   -0.913794      -3.393229  -1.393616
# 3135   1.293909       4.278487    1.819050       5.886168  -1.445144
# 3136   1.571401       3.944179    0.223943      -3.393229  -1.298905
# 3137   1.106863       3.664495    0.000999      -3.393229  -1.479618
# 3138   1.299224       4.181909    0.000999      -3.393229  -1.157150
# 3139   1.409343       5.060876    0.337186      -3.393229  -1.397391
# 3140   1.774398       7.096103    1.098946      -3.393229  -1.227161
#
#       mean_mg_pct_ln  pct_irrigated_acres_ln  herbicides_ln  a_diesel_ln  \
# 0          -2.830218               -3.337657       8.400212    -0.945113
# 1          -3.194183               -3.753551      10.272160    -0.847797
# 2          -3.540459               -2.943446       8.526230    -1.610417
# 3          -2.273026               -6.258714       6.650768    -1.552017
# 4          -2.024953               -4.291503       8.094220    -1.203375
# 5          -2.995732               -4.310303       6.938448    -1.828778
# 6          -3.101093              -13.002900       8.074779    -1.575155
# 7          -1.474033               -3.947187       8.529477    -0.693482
# 8          -1.024433               -4.796460       5.888609    -1.143347
# 9          -1.883875               -3.332589       9.409874    -1.286515
# 10         -2.488915               -4.351473       7.497436    -1.441023
# 11         -2.918771               -7.549135       5.785130    -2.069802
# 12         -3.146555               -7.094877       6.667040    -2.118936
# 13         -1.619488               -5.215387       6.093845    -1.494002
# 14         -1.180907              -13.002900       6.715755    -1.298986
# 15         -3.540459               -2.734039       9.222133    -1.472836
# 16         -2.017406               -4.093133       9.888943    -0.787201
# 17         -3.863233               -6.919511       8.284603    -1.949244
# 18         -1.537117               -5.905434       2.692026    -1.562246
# 19         -4.268698               -4.174922       8.350126    -1.732356
# 20         -3.352407               -4.730564       8.170191    -1.941586
# 21         -2.171557               -4.435858       9.352320    -1.172106
# 22         -3.540459               -2.586289       8.796891    -1.234906
# 23         -2.225624               -4.110280       9.115271    -1.581082
# 24         -2.322788               -4.705837      10.879550    -1.126485
# 25         -2.162823               -3.753743       8.510628    -1.114515
# 26         -4.135167               -4.112655       8.927216    -1.534311
# 27         -1.838851               -5.169814       8.380006    -0.782096
# 28         -2.292635              -13.002900       8.881796    -1.733717
# 29         -2.145581               -4.425322       8.540205    -1.448877
# ...              ...                     ...            ...          ...
# 3111       -0.689155               -4.007967       9.617401    -1.945415
# 3112        1.516445               -4.686563      10.993930    -0.435315
# 3113        1.017764               -4.502483      10.985020    -0.178873
# 3114       -0.228156               -3.067080      11.353090    -1.239589
# 3115       -0.287682               -1.586453      11.108190    -1.318545
# 3116        0.825052               -4.845714      11.345130    -0.428865
# 3117       -1.007858               -2.322515      10.816070    -1.119833
# 3118       -0.017146               -0.826246      -2.184802    -1.266565
# 3119        0.125751               -1.652949       7.190487    -3.572653
# 3120       -0.328504               -2.538077       6.167274    -2.175787
# 3121       -0.149661               -1.062269       4.317000    -2.397456
# 3122       -0.489390               -0.881344       5.160130    -2.532063
# 3123       -0.231932               -2.188973       5.336904    -3.341455
# 3124        0.028587               -1.645701       6.733572    -2.780242
# 3125       -0.269188               -0.595009       9.612343    -2.136633
# 3126        0.281413               -0.637824       5.594956    -3.648473
# 3127        0.038259               -0.794685       3.970826    -2.608443
# 3128       -0.279714               -0.449378       9.573338    -1.218226
# 3129        0.211071               -2.095403       5.276856    -2.668772
# 3130       -0.160169               -0.859080       5.714878    -1.731766
# 3131       -0.204567               -1.537173       6.889414    -2.963425
# 3132        0.573237               -1.934131       6.597585    -2.606282
# 3133       -0.015114               -0.444171       7.903292    -2.545363
# 3134        0.046884               -0.369219       5.764328    -1.481953
# 3135        0.172271               -1.868457       4.711172    -3.676730
# 3136        0.156149               -3.354520       3.650184    -1.586659
# 3137        0.200489               -3.898750      -2.184802    -2.513808
# 3138        0.230318               -0.580482      -2.184802    -2.411864
# 3139       -0.119910               -1.492831       6.483707    -1.847486
# 3140       -0.104250               -1.897846       5.107015    -2.816425
#
#       pct_disease_acres_ln
# 0                -4.912754
# 1                -4.463170
# 2                -4.839575
# 3               -11.077190
# 4                -6.651126
# 5                -5.665875
# 6                -7.818559
# 7                -7.174303
# 8               -14.531490
# 9                -7.153907
# 10               -5.373405
# 11              -10.380520
# 12              -14.531490
# 13              -10.367770
# 14              -10.377500
# 15               -3.513239
# 16               -7.192561
# 17              -14.531490
# 18              -11.797520
# 19               -4.846103
# 20               -6.374792
# 21               -6.136907
# 22               -4.023850
# 23               -5.230067
# 24               -5.819068
# 25               -4.505020
# 26               -6.636046
# 27               -9.003927
# 28              -14.531490
# 29              -10.147910
# ...                    ...
# 3111             -6.630676
# 3112             -6.043386
# 3113             -6.314795
# 3114             -6.247169
# 3115             -2.882572
# 3116            -10.720440
# 3117             -5.883873
# 3118            -14.531490
# 3119             -9.186805
# 3120            -14.531490
# 3121            -14.531490
# 3122             -9.352329
# 3123            -14.531490
# 3124            -14.531490
# 3125             -7.379066
# 3126            -14.531490
# 3127            -14.531490
# 3128             -7.354054
# 3129            -14.531490
# 3130            -14.531490
# 3131            -14.531490
# 3132             -6.898974
# 3133             -8.651827
# 3134            -14.531490
# 3135            -14.531490
# 3136            -14.531490
# 3137            -14.531490
# 3138            -12.373040
# 3139             -7.328176
# 3140            -14.531490
#
# [3141 rows x 10 columns]

# %%
data1.describe()
# Out:
#          hg_ln_ave  a_so2_mean_ln   w_alpha_ln  fungicides_ln    ca_ln_ave  \
# count  3141.000000   3.141000e+03  3141.000000    3141.000000  3141.000000
# mean      2.860845   4.462560e+00    -3.977843       2.407364    -1.809540
# std       0.858815   1.534491e+00     3.751304       4.295629     0.620641
# min       0.064667   1.270000e-09    -6.907755      -3.393229    -3.335712
# 25%       2.313111   3.415786e+00    -6.907755      -3.393229    -2.374238
# 50%       3.217554   4.791209e+00    -6.907755       3.346446    -1.807539
# 75%       3.535343   5.628846e+00     0.521370       5.737571    -1.276535
# max       3.838070   9.407594e+00     3.940630      13.163920    -0.152018
#
#        mean_mg_pct_ln  pct_irrigated_acres_ln  herbicides_ln  a_diesel_ln  \
# count     3141.000000             3141.000000    3141.000000  3141.000000
# mean        -1.029600               -4.525457       8.486911    -1.392137
# std          1.278243                3.344372       4.011897     0.935476
# min         -6.214608              -13.002900      -2.184802    -8.339677
# 25%         -1.514128               -5.229104       6.738090    -1.830281
# 50%         -0.725670               -3.821211       9.326432    -1.308009
# 75%         -0.196015               -2.388031      11.558170    -0.823834
# max          1.608838                0.016658      13.979230     2.176477
#
#        pct_disease_acres_ln
# count           3141.000000
# mean              -8.010102
# std                3.680040
# min              -14.531490
# 25%               -9.622916
# 50%               -6.982937
# 75%               -5.381075
# max               -1.447976

# %% [markdown]
# What is the best predictor of mercury levels in water?

# %% [markdown]
# Dependent variables (response):
#
# Hg_ln_ave - Total Mercury deposition in water (ng/M2)
#
#
# Independent variables(features):
#
# 'w_alpha_ln','fungicides_ln','ca_ln_ave','mean_mg_pct_ln','pct_irrigated_acres_ln','herbicides_ln','a_diesel_ln','pct_disease_acres_ln'

# %%
# visualize the relationship between the features and the response using scatterplots
fig, axs = plt.subplots(1, 3, sharey=True)
data1.plot(kind='scatter', x='pct_irrigated_acres_ln', y='hg_ln_ave', ax=axs[0], figsize=(30, 8))
data1.plot(kind='scatter', x='herbicides_ln', y='hg_ln_ave', ax=axs[2])

# %%
fig, axs = plt.subplots(1, 3, sharey=True)
data1.plot(kind='scatter', x='w_alpha_ln', y='hg_ln_ave', ax=axs[0], figsize=(30, 8))
data1.plot(kind='scatter', x='mean_mg_pct_ln', y='hg_ln_ave', ax=axs[1])
data1.plot(kind='scatter', x='pct_disease_acres_ln', y='hg_ln_ave', ax=axs[2])

# %%
fig, axs = plt.subplots(1, 4, sharey=True)
data1.plot(kind='scatter', x='fungicides_ln', y='hg_ln_ave', ax=axs[0], figsize=(30, 8))
data1.plot(kind='scatter', x='ca_ln_ave', y='hg_ln_ave', ax=axs[1])
data1.plot(kind='scatter', x='a_diesel_ln', y='hg_ln_ave', ax=axs[2])
data1.plot(kind='scatter', x='a_so2_mean_ln', y='hg_ln_ave', ax=axs[3])

# %% [markdown]
#  Relationships are unclear

# %%
import statsmodels.formula.api as smf

lm = smf.ols(formula='hg_ln_ave ~ a_so2_mean_ln + w_alpha_ln + fungicides_ln + ca_ln_ave + mean_mg_pct_ln + pct_irrigated_acres_ln + herbicides_ln + a_diesel_ln + pct_disease_acres_ln', data=data1).fit()

lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              hg_ln_ave   R-squared:                       0.554
# Model:                            OLS   Adj. R-squared:                  0.553
# Method:                 Least Squares   F-statistic:                     432.4
# Date:                Fri, 19 May 2017   Prob (F-statistic):               0.00
# Time:                        12:19:22   Log-Likelihood:                -2709.7
# No. Observations:                3141   AIC:                             5439.
# Df Residuals:                    3131   BIC:                             5500.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------------
# Intercept                  0.7667      0.084      9.099      0.000         0.601     0.932
# a_so2_mean_ln              0.2463      0.008     30.330      0.000         0.230     0.262
# w_alpha_ln                -0.0113      0.003     -4.071      0.000        -0.017    -0.006
# fungicides_ln              0.0164      0.003      5.160      0.000         0.010     0.023
# ca_ln_ave                 -0.2915      0.021    -13.754      0.000        -0.333    -0.250
# mean_mg_pct_ln            -0.1489      0.009    -17.185      0.000        -0.166    -0.132
# pct_irrigated_acres_ln    -0.0383      0.003    -11.161      0.000        -0.045    -0.032
# herbicides_ln              0.0303      0.004      7.985      0.000         0.023     0.038
# a_diesel_ln                0.1711      0.014     12.388      0.000         0.144     0.198
# pct_disease_acres_ln      -0.0047      0.003     -1.395      0.163        -0.011     0.002
# ==============================================================================
# Omnibus:                      846.421   Durbin-Watson:                   0.729
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2658.867
# Skew:                          -1.360   Prob(JB):                         0.00
# Kurtosis:                       6.593   Cond. No.                         123.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
lm.params
# Out:
# Intercept                 0.766681
# a_so2_mean_ln             0.246270
# w_alpha_ln               -0.011299
# fungicides_ln             0.016448
# ca_ln_ave                -0.291538
# mean_mg_pct_ln           -0.148913
# pct_irrigated_acres_ln   -0.038323
# herbicides_ln             0.030270
# a_diesel_ln               0.171111
# pct_disease_acres_ln     -0.004699
# dtype: float64

# %%
lm.pvalues
# Out:
# Intercept                  1.588014e-19
# a_so2_mean_ln             2.227843e-177
# w_alpha_ln                 4.794960e-05
# fungicides_ln              2.617656e-07
# ca_ln_ave                  7.723445e-42
# mean_mg_pct_ln             2.547471e-63
# pct_irrigated_acres_ln     2.157793e-28
# herbicides_ln              1.960921e-15
# a_diesel_ln                1.920902e-34
# pct_disease_acres_ln       1.631796e-01
# dtype: float64

# %%
lm = smf.ols(formula='hg_ln_ave ~ a_diesel_ln + ca_ln_ave + a_so2_mean_ln', data=data1).fit()

lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              hg_ln_ave   R-squared:                       0.476
# Model:                            OLS   Adj. R-squared:                  0.475
# Method:                 Least Squares   F-statistic:                     948.4
# Date:                Fri, 19 May 2017   Prob (F-statistic):               0.00
# Time:                        12:18:40   Log-Likelihood:                -2964.5
# No. Observations:                3141   AIC:                             5937.
# Df Residuals:                    3137   BIC:                             5961.
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept         1.2130      0.062     19.475      0.000         1.091     1.335
# a_diesel_ln       0.1508      0.014     10.700      0.000         0.123     0.178
# ca_ln_ave        -0.3328      0.018    -18.191      0.000        -0.369    -0.297
# a_so2_mean_ln     0.2814      0.009     33.084      0.000         0.265     0.298
# ==============================================================================
# Omnibus:                      892.284   Durbin-Watson:                   0.548
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2710.693
# Skew:                          -1.452   Prob(JB):                         0.00
# Kurtosis:                       6.505   Cond. No.                         30.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
lm.params
# Out:
# Intercept        1.213034
# a_diesel_ln      0.150816
# ca_ln_ave       -0.332797
# a_so2_mean_ln    0.281354
# dtype: float64

# %%
lm.pvalues
# Out:
# Intercept         7.748791e-80
# a_diesel_ln       2.869057e-26
# ca_ln_ave         2.248353e-70
# a_so2_mean_ln    3.676476e-206
# dtype: float64

# %%
lm = smf.ols(formula='hg_ln_ave ~ a_diesel_ln', data=data1).fit()

lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              hg_ln_ave   R-squared:                       0.227
# Model:                            OLS   Adj. R-squared:                  0.227
# Method:                 Least Squares   F-statistic:                     922.6
# Date:                Fri, 19 May 2017   Prob (F-statistic):          6.83e-178
# Time:                        12:18:48   Log-Likelihood:                -3573.6
# No. Observations:                3141   AIC:                             7151.
# Df Residuals:                    3139   BIC:                             7163.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# Intercept       3.4700      0.024    143.626      0.000         3.423     3.517
# a_diesel_ln     0.4376      0.014     30.375      0.000         0.409     0.466
# ==============================================================================
# Omnibus:                      844.303   Durbin-Watson:                   0.393
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2380.192
# Skew:                          -1.402   Prob(JB):                         0.00
# Kurtosis:                       6.213   Cond. No.                         3.81
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
lm.params
# Out:
# Intercept      3.469977
# a_diesel_ln    0.437552
# dtype: float64

# %%
lm.pvalues
# Out:
# Intercept       0.000000e+00
# a_diesel_ln    6.832897e-178
# dtype: float64

# %% [markdown]
# Interpreting coefficients:
#
# 1 unit increase in a_diesel_ln is equal to a .437552 "unit" increase in hg_ln_ave

# %%
#correlation and heatmap of features i chose to look at 

import seaborn as sns
sns.set_style("darkgrid")

cmap = sns.diverging_palette(220, 10, as_cmap=True)

correlations = data1.corr()
print correlations
print sns.heatmap(correlations, cmap=cmap)
# Out:
#                         hg_ln_ave  a_so2_mean_ln  w_alpha_ln  fungicides_ln  \
# hg_ln_ave                1.000000       0.624025   -0.120304       0.221850
# a_so2_mean_ln            0.624025       1.000000   -0.032839       0.149882
# w_alpha_ln              -0.120304      -0.032839    1.000000      -0.062478
# fungicides_ln            0.221850       0.149882   -0.062478       1.000000
# ca_ln_ave               -0.347700      -0.146638    0.025894      -0.187653
# mean_mg_pct_ln          -0.223280       0.005772    0.030029       0.154590
# pct_irrigated_acres_ln  -0.205208      -0.155960    0.080213       0.186261
# herbicides_ln            0.114565       0.153427   -0.054704       0.523311
# a_diesel_ln              0.476609       0.523790   -0.103342       0.145012
# pct_disease_acres_ln     0.149909       0.107408    0.013904       0.395068
#
#                         ca_ln_ave  mean_mg_pct_ln  pct_irrigated_acres_ln  \
# hg_ln_ave               -0.347700       -0.223280               -0.205208
# a_so2_mean_ln           -0.146638        0.005772               -0.155960
# w_alpha_ln               0.025894        0.030029                0.080213
# fungicides_ln           -0.187653        0.154590                0.186261
# ca_ln_ave                1.000000        0.258026                0.054073
# mean_mg_pct_ln           0.258026        1.000000                0.116035
# pct_irrigated_acres_ln   0.054073        0.116035                1.000000
# herbicides_ln            0.308782        0.267940                0.307707
# a_diesel_ln             -0.203807        0.099900                0.007406
# pct_disease_acres_ln    -0.189129        0.012144                0.322321
#
#                         herbicides_ln  a_diesel_ln  pct_disease_acres_ln
# hg_ln_ave                    0.114565     0.476609              0.149909
# a_so2_mean_ln                0.153427     0.523790              0.107408
# w_alpha_ln                  -0.054704    -0.103342              0.013904
# fungicides_ln                0.523311     0.145012              0.395068
# ca_ln_ave                    0.308782    -0.203807             -0.189129
# mean_mg_pct_ln               0.267940     0.099900              0.012144
# pct_irrigated_acres_ln       0.307707     0.007406              0.322321
# herbicides_ln                1.000000     0.201516              0.362419
# a_diesel_ln                  0.201516     1.000000              0.271836
# pct_disease_acres_ln         0.362419     0.271836              1.000000
# Axes(0.125,0.11;0.62x0.77)

# %%
from sklearn import feature_selection, linear_model


def get_linear_model_metrics(X, y, algo):
    # get the pvalue of X given y. Ignore f-stat for now.
    pvals = feature_selection.f_regression(X, y)[1]
    # start with an empty linear regression object
    # .fit() runs the linear regression function on X and y
    algo.fit(X,y)
    residuals = (y-algo.predict(X)).values

    # print the necessary values
    print 'P Values:', pvals
    print 'Coefficients:', algo.coef_
    print 'y-intercept:', algo.intercept_
    print 'R-Squared:', algo.score(X,y)
    plt.figure()
    plt.hist(residuals, bins=np.ceil(np.sqrt(len(y))))
    # keep the model
    return algo

# %% [markdown]
# best predictors:
# a_so2_mean_ln
# ca_ln_ave
# mean_mg_pct_ln
# a_diesel_ln
#
# worst:
# pct_disease_acres_ln
# w_alpha_ln
# fungicides_ln
# herbicides_ln

# %%
y = data1['hg_ln_ave']
x_sets = (
    ['a_diesel_ln'],
    ['a_so2_mean_ln'],
    ['ca_ln_ave'],
    ['mean_mg_pct_ln'],
    ['a_diesel_ln', 'a_so2_mean_ln'],
)

for x in x_sets:
    get_linear_model_metrics(data1[x], y, linear_model.LinearRegression())
    print
# Out:
# P Values: [  6.83289724e-178]
# Coefficients: [ 0.43755197]
# y-intercept: 3.46997729429
# R-Squared: 0.227156471098
#
# P Values: [ 0.]
# Coefficients: [ 0.34925032]
# y-intercept: 1.30229479929
# R-Squared: 0.389406607787
#
# P Values: [  6.06535277e-90]
# Coefficients: [-0.48113211]
# y-intercept: 1.9902174019
# R-Squared: 0.120895524064
#
# P Values: [  8.79033228e-37]
# Coefficients: [-0.15001552]
# y-intercept: 2.70638915077
# R-Squared: 0.0498540050426
#
# P Values: [  6.83289724e-178   0.00000000e+000]
# Coefficients: [ 0.18945893  0.28875244]
# y-intercept: 1.83602288017
# R-Squared: 0.420310968933

# %%
#need to do cross validation (generate several models on different cross sections of the data)
#need to specify dependent and independent variables here and then do the k-means cross validation 
x = data1[['a_diesel_ln','a_so2_mean_ln']]
y = data1[['hg_ln_ave']]

# %%
y.head()
# Out:
#    hg_ln_ave
# 0   3.584468
# 1   3.579431
# 2   3.494634
# 3   3.606218
# 4   3.565559

# %%
x.head()
# Out:
#    a_diesel_ln  a_so2_mean_ln
# 0    -0.945113       2.366601
# 1    -0.847797       2.841814
# 2    -1.610417       3.146611
# 3    -1.552017       2.032213
# 4    -1.203375       2.187600

# %%
#cross validation with 5 folds 
from sklearn import cross_validation

kf = cross_validation.KFold(len(data1), n_folds=5, shuffle=True)

# %%
mse_values = []
scores = []
n= 0
print "~~~~ CROSS VALIDATION each fold ~~~~"
for train_index, test_index in kf:
    lm = linear_model.LinearRegression().fit(x.iloc[train_index], y.iloc[train_index])
    mse_values.append(metrics.mean_squared_error(y.iloc[test_index], lm.predict(x.iloc[test_index])))
    scores.append(lm.score(x, y))
    n+=1
    print 'Model', n
    print 'MSE:', mse_values[n-1]
    print 'R2:', scores[n-1]


print "~~~~ SUMMARY OF CROSS VALIDATION ~~~~"
print 'Mean of MSE for all folds:', np.mean(mse_values)
print 'Mean of R2 for all folds:', np.mean(scores)
# Out:
# ~~~~ CROSS VALIDATION each fold ~~~~
# Model 1
# MSE: 0.512928444102
# R2: 0.420002499511
# Model 2
# MSE: 0.389516111407
# R2: 0.420268518824
# Model 3
# MSE: 0.389313696056
# R2: 0.420241177449
# Model 4
# MSE: 0.452908444011
# R2: 0.420272148989
# Model 5
# MSE: 0.395586003769
# R2: 0.420272252095
# ~~~~ SUMMARY OF CROSS VALIDATION ~~~~
# Mean of MSE for all folds: 0.428050539869
# Mean of R2 for all folds: 0.420211319374

# %%
lm = linear_model.LinearRegression().fit(x, y)
print "~~~~ Single Model ~~~~"
print 'MSE of single model:', metrics.mean_squared_error(y, lm.predict(x))
print 'R2: ', lm.score(x, y)
# Out:
# ~~~~ Single Model ~~~~
# MSE of single model: 0.427421047122
# R2:  0.420310968933

# %%
lm = linear_model.LinearRegression().fit(x, y)
print "~~~ OLS ~~~"
print 'OLS MSE: ', metrics.mean_squared_error(y, lm.predict(x))
print 'OLS R2:', lm.score(x, y)

lm = linear_model.Lasso().fit(x, y)
print "~~~ Lasso ~~~"
print 'Lasso MSE: ', metrics.mean_squared_error(y, lm.predict(x))
print 'Lasso R2:', lm.score(x, y)

lm = linear_model.Ridge().fit(x, y)
print "~~~ Ridge ~~~"
print 'Ridge MSE: ', metrics.mean_squared_error(y, lm.predict(x))
print 'Ridge R2:', lm.score(x, y)
# Out:
# ~~~ OLS ~~~
# OLS MSE:  0.427421047122
# OLS R2: 0.420310968933
# ~~~ Lasso ~~~
# Lasso MSE:  0.737328160816
# Lasso R2: 0.0
# ~~~ Ridge ~~~
# Ridge MSE:  0.42742105222
# Ridge R2: 0.420310962018

# %%
from sklearn import grid_search

alphas = np.logspace(-10, 10, 21)
gs = grid_search.GridSearchCV(
    estimator=linear_model.Ridge(),
    param_grid={'alpha': alphas},
    scoring='mean_squared_error')

gs.fit(x, y)
# Out:
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /anaconda/lib/python2.7/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# GridSearchCV(cv=None, error_score='raise',
#        estimator=Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001),
#        fit_params={}, iid=True, n_jobs=1,
#        param_grid={'alpha': array([  1.00000e-10,   1.00000e-09,   1.00000e-08,   1.00000e-07,
#          1.00000e-06,   1.00000e-05,   1.00000e-04,   1.00000e-03,
#          1.00000e-02,   1.00000e-01,   1.00000e+00,   1.00000e+01,
#          1.00000e+02,   1.00000e+03,   1.00000e+04,   1.00000e+05,
#          1.00000e+06,   1.00000e+07,   1.00000e+08,   1.00000e+09,
#          1.00000e+10])},
#        pre_dispatch='2*n_jobs', refit=True, scoring='mean_squared_error',
#        verbose=0)

# %%
print gs.best_score_
# Out:
# -0.455612234735

# %%
print -gs.best_score_
# Out:
# 0.455612234735

# %%
print gs.best_estimator_
# Out:
# Ridge(alpha=1000.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
print gs.grid_scores_
# Out:
# [mean: -0.46020, std: 0.11456, params: {'alpha': 1e-10}, mean: -0.46020, std: 0.11456, params: {'alpha': 1.0000000000000001e-09}, mean: -0.46020, std: 0.11456, params: {'alpha': 1e-08}, mean: -0.46020, std: 0.11456, params: {'alpha': 9.9999999999999995e-08}, mean: -0.46020, std: 0.11456, params: {'alpha': 9.9999999999999995e-07}, mean: -0.46020, std: 0.11456, params: {'alpha': 1.0000000000000001e-05}, mean: -0.46020, std: 0.11456, params: {'alpha': 0.0001}, mean: -0.46020, std: 0.11456, params: {'alpha': 0.001}, mean: -0.46020, std: 0.11456, params: {'alpha': 0.01}, mean: -0.46020, std: 0.11455, params: {'alpha': 0.10000000000000001}, mean: -0.46018, std: 0.11454, params: {'alpha': 1.0}, mean: -0.46000, std: 0.11441, params: {'alpha': 10.0}, mean: -0.45839, std: 0.11320, params: {'alpha': 100.0}, mean: -0.45561, std: 0.10762, params: {'alpha': 1000.0}, mean: -0.56403, std: 0.09901, params: {'alpha': 10000.0}, mean: -0.71278, std: 0.09880, params: {'alpha': 100000.0}, mean: -0.74104, std: 0.09927, params: {'alpha': 1000000.0}, mean: -0.74410, std: 0.09932, params: {'alpha': 10000000.0}, mean: -0.74441, std: 0.09933, params: {'alpha': 100000000.0}, mean: -0.74444, std: 0.09933, params: {'alpha': 1000000000.0}, mean: -0.74444, std: 0.09933, params: {'alpha': 10000000000.0}]

# %%
sns.lmplot('a_so2_mean_ln', 'hg_ln_ave', data1, scatter=False)

# %%
data1.smplot(x='a_so2_mean_ln', y ='hg_ln_ave')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-590-6eea16f10f6d> in <module>()
# ----> 1 data1.smplot(x='a_so2_mean_ln', y ='hg_ln_ave')
#
# /anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    2742             if name in self._info_axis:
#    2743                 return self[name]
# -> 2744             return object.__getattribute__(self, name)
#    2745
#    2746     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'smplot'

# %%
sns.lmplot('ca_ln_ave','hg_ln_ave', data1)

# %%
sns.lmplot('a_diesel_ln', 'hg_ln_ave', data1)

# %%
sns.lmplot('mean_mg_pct_ln', 'hg_ln_ave', data1)

# %%
sns.lmplot('pct_disease_acres_ln', 'hg_ln_ave', data1)

# %%
sns.lmplot('w_alpha_ln', 'hg_ln_ave', data1)

# %% [markdown]
# probability of high mercury in water based on type of pollutant
#
# could do probability of high mercury based on state

# %%
air_data = data[['hg_ln_ave','a_so2_mean_ln','a_diesel_ln','a_co_mean_ln','a_hg_ln']]

# %%
air_data.head()
# Out:
#    hg_ln_ave  a_so2_mean_ln  a_diesel_ln  a_co_mean_ln   a_hg_ln
# 0   3.584468       2.366601    -0.945113      1.495872 -7.179439
# 1   3.579431       2.841814    -0.847797      2.555352 -7.162792
# 2   3.494634       3.146611    -1.610417      2.976577 -7.188689
# 3   3.606218       2.032213    -1.552017      1.082475 -7.178229
# 4   3.565559       2.187600    -1.203375      2.236682 -7.177865

# %%
water_data = data[['hg_ln_ave','ca_ln_ave','w_alpha_ln','mg_ln_ave','so4_mean_ave']]

# %%
water_data.head()
# Out:
#    hg_ln_ave  ca_ln_ave  w_alpha_ln  mg_ln_ave  so4_mean_ave
# 0   3.584468  -2.430771   -6.907755  -3.203389      1.052519
# 1   3.579431  -2.352988    0.984323  -2.951081      0.997515
# 2   3.494634  -2.492509    1.139754  -2.909043      0.981464
# 3   3.606218  -2.381515   -0.355247  -3.199517      1.046325
# 4   3.565559  -2.387422    1.098946  -3.278341      1.204334

# %%
land_data = data[['hg_ln_ave','mean_mg_pct_ln','pct_disease_acres_ln','fungicides_ln','herbicides_ln']]

# %%
land_data.head()
# Out:
#    hg_ln_ave  mean_mg_pct_ln  pct_disease_acres_ln  fungicides_ln  \
# 0   3.584468       -2.830218             -4.912754       2.314664
# 1   3.579431       -3.194183             -4.463170       8.670521
# 2   3.494634       -3.540459             -4.839575       2.260807
# 3   3.606218       -2.273026            -11.077190       0.106351
# 4   3.565559       -2.024953             -6.651126       2.996326
#
#    herbicides_ln
# 0       8.400212
# 1      10.272160
# 2       8.526230
# 3       6.650768
# 4       8.094220

# %%
a = air_data['hg_ln_ave']
p = np.percentile(a, 90) 
print p
# Out:
# 3.655383

# %%
bins = [0, 3.655382, 3.838070]

# %%
group_names = ['Low', 'High']

# %%
hg_air_categories = pd.cut(air_data['hg_ln_ave'], bins, labels=group_names)
air_data['hg_air_categories'] = pd.cut(air_data['hg_ln_ave'], bins, labels=group_names)
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
pd.value_counts(air_data['hg_air_categories'])
# Out:
# Low     2826
# High     315
# Name: hg_air_categories, dtype: int64

# %%
air_data.head()
# Out:
#    hg_ln_ave  a_so2_mean_ln  a_diesel_ln  a_co_mean_ln   a_hg_ln  \
# 0   3.584468       2.366601    -0.945113      1.495872 -7.179439
# 1   3.579431       2.841814    -0.847797      2.555352 -7.162792
# 2   3.494634       3.146611    -1.610417      2.976577 -7.188689
# 3   3.606218       2.032213    -1.552017      1.082475 -7.178229
# 4   3.565559       2.187600    -1.203375      2.236682 -7.177865
#
#   hg_air_categories
# 0               Low
# 1               Low
# 2               Low
# 3               Low
# 4               Low

# %%
# %matplotlib inline

# %%
from sklearn.linear_model import LogisticRegression
import sklearn.linear_model as lm

air_features += air_data[['a_so2_mean_ln']]

logreg = lm.LogisticRegression()
logreg.fit(air_features, air_data['hg_air_categories']) 

air_data['probability'] = logreg.predict_proba(air_data[air_features[1:]]).T[1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-620-a012951aa3ee> in <module>()
#       7 logreg.fit(air_features, air_data['hg_air_categories'])
#       8
# ----> 9 air_data['probability'] = logreg.predict_proba(air_data[air_features[1:]]).T[1]
#      10
#
# /anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2053             return self._getitem_array(key)
#    2054         elif isinstance(key, DataFrame):
# -> 2055             return self._getitem_frame(key)
#    2056         elif is_mi_columns:
#    2057             return self._getitem_multilevel(key)
#
# /anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_frame(self, key)
#    2128     def _getitem_frame(self, key):
#    2129         if key.values.size and not is_bool_dtype(key.values):
# -> 2130             raise ValueError('Must pass DataFrame with boolean values only')
#    2131         return self.where(key)
#    2132
#
# ValueError: Must pass DataFrame with boolean values only

# %%
ax = plt.subplot(111)
colors = ['blue', 'green', 'red', 'purple']
for e, c in enumerate(colors):
    air_data[air_data[air_features[e]] == 1].plot(x='CRS_DEP_TIME', y='probability', kind='scatter', color = c, ax=ax)

ax.set(title='Probability of High Mercury in Water based on Various Air Pollutant Levels')

# %%
NY_data = data[data['hg_ln_ave'].notnull() & (data['state'] == "NY")]

# %%
NY_data.head()
# Out:
#       stfips        county_name state   fips  cat_rucc  a_teca_ln  \
# 1825   36001      Albany County    NY  36001         1  -3.723848
# 1826   36003    Allegany County    NY  36003         3  -5.155907
# 1827   36005       Bronx County    NY  36005         1  -3.123127
# 1828   36007      Broome County    NY  36007         1  -3.836771
# 1829   36009  Cattaraugus Count    NY  36009         2  -4.255908
#
#       a_112tca_ln  a_dbcp_ln  a_tdi_ln  a_2clacephen_ln        ...         \
# 1825    -11.52867  -12.39098 -9.028506        -31.70556        ...
# 1826    -17.30033  -12.39889 -9.941418        -31.70556        ...
# 1827    -11.35898  -11.05813 -6.350526        -15.74627        ...
# 1828    -12.28193  -12.22641 -9.210086        -15.75284        ...
# 1829    -15.02608  -12.43549 -6.453063        -17.67771        ...
#
#       med_hh_value  med_hh_inc  pct_pers_lt_pov  pct_no_eng  pct_hs_more  \
# 1825        116300       42935             10.6         9.9         86.3
# 1826         50400       32106             15.5         4.1         83.2
# 1827        190400       27611             30.7        52.7         62.3
# 1828         75800       35347             12.8         8.9         83.8
# 1829         60800       33404             13.7         5.1         81.2
#
#       pct_unemp  med_rooms  work_out_co  pct_mt_10units_log  violent_rate_log
# 1825        6.8        5.6         17.0            2.420368          6.169140
# 1826        9.0        5.5         29.7            0.615186          4.459856
# 1827       14.3        3.6         59.3            4.233382          5.404572
# 1828        5.4        5.6          8.5            1.924249          5.749844
# 1829        7.4        5.7         28.8            0.974560          4.932854
#
# [5 rows x 227 columns]

# %%
NY_data.shape
# Out:
# (62, 227)

# %%
import geopandas as gpd
from geopandas import GeoSeries, GeoDataFrame

# %%
NY_data1 = NY_data[['hg_ln_ave','a_so2_mean_ln','w_alpha_ln','fungicides_ln','ca_ln_ave','mean_mg_pct_ln','pct_irrigated_acres_ln','herbicides_ln','a_diesel_ln','pct_disease_acres_ln']]

# %%
NY_data1.head()
# Out:
#       hg_ln_ave  a_so2_mean_ln  w_alpha_ln  fungicides_ln  ca_ln_ave  \
# 1825   3.781484       5.506350   -6.907755       2.687725  -2.429174
# 1826   3.739251       5.587924   -6.907755       8.993171  -2.239720
# 1827   3.671819       5.544772   -6.907755      -3.393229  -2.360741
# 1828   3.755112       5.709922   -6.907755      -3.393229  -2.259573
# 1829   3.724324       5.805923   -6.907755       3.850424  -2.133204
#
#       mean_mg_pct_ln  pct_irrigated_acres_ln  herbicides_ln  a_diesel_ln  \
# 1825       -0.409473               -4.482021       8.180659    -0.127534
# 1826       -0.663588               -5.334507       9.423717    -1.888407
# 1827       -0.497580              -13.002900      -2.184802     0.972571
# 1828       -0.740239               -4.943982       8.532845    -0.917527
# 1829       -0.524249               -4.804524       9.525079    -1.670048
#
#       pct_disease_acres_ln
# 1825             -7.167595
# 1826             -6.513144
# 1827            -14.531490
# 1828             -5.892180
# 1829             -8.125444

# %%
fig, axs = plt.subplots(1, 4, sharey=True)
NY_data1.plot(kind='scatter', x='fungicides_ln', y='hg_ln_ave', ax=axs[0], figsize=(30, 8))
NY_data1.plot(kind='scatter', x='ca_ln_ave', y='hg_ln_ave', ax=axs[1])
NY_data1.plot(kind='scatter', x='a_diesel_ln', y='hg_ln_ave', ax=axs[2])
NY_data1.plot(kind='scatter', x='a_so2_mean_ln', y='hg_ln_ave', ax=axs[3])

# %%
sns.lmplot('a_so2_mean_ln', 'hg_ln_ave', NY_data1)

# %%
import statsmodels.formula.api as smf

lm = smf.ols(formula='hg_ln_ave ~ a_so2_mean_ln + w_alpha_ln + fungicides_ln + ca_ln_ave + mean_mg_pct_ln + pct_irrigated_acres_ln + herbicides_ln + a_diesel_ln + pct_disease_acres_ln', data=NY_data1).fit()

lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              hg_ln_ave   R-squared:                       0.617
# Model:                            OLS   Adj. R-squared:                  0.551
# Method:                 Least Squares   F-statistic:                     9.320
# Date:                Fri, 19 May 2017   Prob (F-statistic):           2.94e-08
# Time:                        14:55:31   Log-Likelihood:                 134.17
# No. Observations:                  62   AIC:                            -248.3
# Df Residuals:                      52   BIC:                            -227.1
# Df Model:                           9
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------------
# Intercept                  2.8995      0.111     26.035      0.000         2.676     3.123
# a_so2_mean_ln              0.0831      0.017      4.806      0.000         0.048     0.118
# w_alpha_ln                -0.0013      0.004     -0.336      0.738        -0.009     0.006
# fungicides_ln             -0.0019      0.002     -1.073      0.288        -0.006     0.002
# ca_ln_ave                 -0.1314      0.032     -4.057      0.000        -0.196    -0.066
# mean_mg_pct_ln             0.0036      0.011      0.319      0.751        -0.019     0.027
# pct_irrigated_acres_ln     0.0002      0.003      0.064      0.949        -0.006     0.007
# herbicides_ln              0.0056      0.003      2.003      0.050     -1.13e-05     0.011
# a_diesel_ln               -0.0177      0.006     -2.858      0.006        -0.030    -0.005
# pct_disease_acres_ln      -0.0022      0.002     -1.099      0.277        -0.006     0.002
# ==============================================================================
# Omnibus:                        7.112   Durbin-Watson:                   2.132
# Prob(Omnibus):                  0.029   Jarque-Bera (JB):                6.886
# Skew:                          -0.815   Prob(JB):                       0.0320
# Kurtosis:                       3.099   Cond. No.                         472.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
lm.params
# Out:
# Intercept                 2.899523
# a_so2_mean_ln             0.083139
# w_alpha_ln               -0.001302
# fungicides_ln            -0.001945
# ca_ln_ave                -0.131402
# mean_mg_pct_ln            0.003644
# pct_irrigated_acres_ln    0.000201
# herbicides_ln             0.005590
# a_diesel_ln              -0.017731
# pct_disease_acres_ln     -0.002208
# dtype: float64

# %%
lm.pvalues
# Out:
# Intercept                 1.697748e-31
# a_so2_mean_ln             1.353330e-05
# w_alpha_ln                7.381023e-01
# fungicides_ln             2.880760e-01
# ca_ln_ave                 1.673044e-04
# mean_mg_pct_ln            7.509671e-01
# pct_irrigated_acres_ln    9.492326e-01
# herbicides_ln             5.044746e-02
# a_diesel_ln               6.113805e-03
# pct_disease_acres_ln      2.770200e-01
# dtype: float64
