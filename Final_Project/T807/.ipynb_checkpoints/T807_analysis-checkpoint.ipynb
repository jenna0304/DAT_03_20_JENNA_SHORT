# %%
#imports
from __future__ import division
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import pylab as pl
import numpy as np
import seaborn as sns
import statsmodels.formula.api as smf
# %matplotlib inline

# %%
data = pd.read_csv("../dataset/T807_Master_Data.csv")
data.head()
# Out:
#      SubNum initials    dx Sex    referral source In UDS? Doc visit complete?  \
# 0  T807_001       EM  mTBI   M             Gandy        Y                   Y
# 1  T807_002       SM  mTBI   M      self-referral       Y                   Y
# 2  T807_003       KG    HC   M          Dickstein       Y                   Y
# 3  T807_004       BS  mTBI   M             Gandy        Y                   Y
# 4  T807_005       GM  mTBI   M  hockey conference       Y                   Y
#
#   Amyvid dose ordered? T807 dose ordered? Amyvid Complete?    ...     \
# 0                    Y                  Y                Y    ...
# 1                    Y                  Y                Y    ...
# 2                    Y                  Y                Y    ...
# 3                    Y                  Y                Y    ...
# 4                    Y                  Y                Y    ...
#
#                                     MRI Safety Read  AMYVID PET RESULT   SUVr  \
# ...

# %%
data.shape
# Out:
# (36, 133)

# %%
data.columns
# Out:
# Index([u'SubNum', u'initials', u'dx', u'Sex', u'referral source', u'In UDS?',
#        u'Doc visit complete?', u'Amyvid dose ordered?', u'T807 dose ordered?',
#        u'Amyvid Complete?',
#        ...
#        u'MRI Safety Read ', u'AMYVID PET RESULT', u'SUVr',
#        u'Amyvid amount Injected (ml)', u'Amyvid dose Injected (mCi)',
#        u'Minutes post injection for scan (Amyvid)',
#        u'T807 amount Injected (ml)', u'T807 dose Injected (mCi)',
#        u'Minutes post injection for scan (T807)', u'T807'],
#       dtype='object', length=133)

# %%
df = data[['MoCA','BDI-II','Age when seen','Education','Categorical # of TBIs','Rivermead','LNS_SS','Similarities_SS','NPI','Coding_SS','Categorical # of TBIs']]

# %%
df.mean()
# Out:
# MoCA                     24.138889
# BDI-II                   15.472222
# Age when seen            49.666667
# Education                15.055556
# Categorical # of TBIs     2.500000
# Rivermead                29.967742
# LNS_SS                    9.212121
# Similarities_SS          11.800000
# NPI                       9.193548
# Categorical # of TBIs     2.500000
# dtype: float64

# %%
df.fillna(df.mean())
# Out:
#     MoCA  BDI-II  Age when seen  Education  Categorical # of TBIs  Rivermead  \
# 0     26      41             49       16.0                      2       39.0
# 1     28      24             39       16.0                      3       46.0
# 2     24       5             53       15.5                      0        NaN
# 3     25       4             53       16.0                      5       18.0
# 4     27      12             59       13.0                      5       34.0
# 5     28       7             39       14.0                      5       46.0
# 6     25      11             57       13.0                      1       31.0
# 7     28      30             45       16.0                      2       13.0
# 8     28       8             62       12.0                      1       14.0
# 9     29       2             49       15.0                      0        NaN
# 10    27       8             46       18.0                      2       18.0
# ...
